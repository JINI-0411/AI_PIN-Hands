# %%
import numpy as np # 길이가 학습데이터 무게가 정답데이터

perch_length = np.array(
    [8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0,
     21.0, 21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5,
     22.5, 22.7, 23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5,
     27.3, 27.5, 27.5, 27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0,
     36.5, 36.0, 37.0, 37.0, 39.0, 39.0, 39.0, 40.0, 40.0, 40.0,
     40.0, 42.0, 43.0, 43.0, 43.5, 44.0]
     )
perch_weight = np.array(
    [5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0,
     110.0, 115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0,
     130.0, 150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0,
     197.0, 218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0,
     514.0, 556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0,
     820.0, 850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0,
     1000.0, 1000.0]
     )

# %%
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(perch_length, perch_weight)

# %%
train_input = train_input.reshape(-1,1)
test_input = test_input.reshape(-1,1)
print(train_input.shape, test_input.shape)
# Out:
# (42, 1) (14, 1)

# %%
from sklearn.neighbors import KNeighborsRegressor
knr = KNeighborsRegressor(n_neighbors=3) # 최근접 이웃의 갯수 기본값 5가 아닌 3으로 변경 - 모델의 복잡도가 높아진다!

knr.fit(train_input, train_target)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
knr.predict([[50,],[100]])
# Out:
# array([1033.33333333, 1033.33333333])

# %%
distances, indexes = knr.kneighbors([[50]])

# %%
distances, indexes = knr.kneighbors([[50]])

# 넘파이 평균 mean
np.mean(train_target[indexes])
# Out:
# 1033.3333333333333

# %%
import matplotlib.pyplot as plt

plt.scatter(train_input, train_target)
plt.scatter(train_input[indexes], train_target[indexes], marker='D') #50cm 길이의 농어 최근접 이웃
plt.scatter(50,1066,marker='^')
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
# 선형 회귀
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# 훈련
lr.fit(train_input, train_target)

# 예측 - 50cm 농어 무게
lr.predict([[50]])
# Out:
# array([1238.90951602])

# %%
# 최적의 기울기 - 계수, 가중치 - lr.coef_ // 기울기에 관한게 여기에.. 기울기를 찾아줌
# 최적의 절편 - lr.intercept_

print(lr.coef_, lr.intercept_) # y = 36.8x - 630.96 : x-길이, y-무게
# Out:
# [39.65436922] -743.808944942235

# %%
# matlotlib - plot : 직선, 곡선 그래프

plt.scatter(train_input, train_target) # 훈련 세트
plt.plot([8,50] ,[8 * lr.coef_[0]+lr.intercept_, 50*lr.coef_[0] + lr.intercept_])
plt.scatter(50,1210, marker="^")
plt.xlabel("length")
plt.ylabel("weight")
# Out:
# Text(0, 0.5, 'weight')

# %%
print(lr.score(train_input, train_target)) # 훈련 세트 결정 계수
print(lr.score(test_input, test_target)) # 테스트 세트 결정 계수
# Out:
# 0.9452012168903423
# 0.8188819217883564

# %%
# 다항회귀 - 2차원 방정식 : y = ax^2 + bx +c / a,b 최적의 가중치(기울기, 계수), c-절편, x-길이, b-무게

# %%
train_poly = np.column_stack((train_input ** 2, train_input))
test_poly = np.column_stack((test_input **2, test_input))

# %%
print(train_poly.shape, test_poly.shape)
# Out:
# (42, 2) (14, 2)

# %%
lr= LinearRegression()
lr.fit(train_poly, train_target)
# Out:
# LinearRegression()

# %%
lr.predict([[50**2, 50]])
# Out:
# array([1595.10744548])

# %%
print(lr.coef_, lr.intercept_)
# Out:
# [  1.14203642 -29.87275741] 233.6542741901098

# %%
# 곡선 - 연속된 x,y 좌표를 제공
point = np.arange(8, 51) # 범위가 8~50 / 길이

plt.scatter(train_input, train_target) # 훈련 세트 산포도
plt.scatter(50, 1647, marker='^')
plt.plot(point, lr.coef_[0] * point **2 + lr.coef_[1] * point + lr.intercept_)
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
print(lr.score(train_poly, train_target)) # 훈련 세트 결정 계수 / 아까 911
print(lr.score(test_poly, test_target)) # 테스트 세트 결정 계수 / 아까 922
# Out:
# 0.9810931176702571
# 0.9466522898742432
