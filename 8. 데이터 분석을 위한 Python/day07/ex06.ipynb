# %%
import requests
url = "https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%B8%94%EB%A1%9C%EA%B7%B8"
response = requests.get(url)
html_text = response.text

# %%
import re
pattern = r"<a.*href=['\"]([^'\"]+)['\"][^>]*>";
p = re.compile(pattern, re.I)
for m in p.finditer(html_text):
    print(m.group(1))
# Out:
# https://help.naver.com/support/alias/search/integration/intergration_84.naver
# javascript:void(0);
# //saedu.naver.com/adbiz/searchad/clickChoice.naver
# https://help.naver.com/service/5626/contents/1419
# https://adcr.naver.com/adcr?x=Dza3m/Bd5mrokIrTD0gAAP///w==...
# https://adcr.naver.com/adcr?x=Dza3m/Bd5mrokIrTD0gAAP///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=Dza3m/Bd5mrokIrTD0gAAP///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=Dza3m/Bd5mrokIrTD0gAAP///w==...&amp;p=0
# https://adcr.naver.com/adcr?x=Dza3m/Bd5mrokIrTD0gAAP///w==...
# https://adcr.naver.com/adcr?x=q+Dz4pDJI+e8j75F+45xnf///w==...
# https://adcr.naver.com/adcr?x=nbNctvB9Z962xuP6xCiNt////w==...
# https://adcr.naver.com/adcr?x=JvJwxFsc3IY6Wp2v9+DUzv///w==...
# https://adcr.naver.com/adcr?x=zh06O6FqnsM96jfnHw+JiP///w==...
# https://adcr.naver.com/adcr?x=4OHXuRmA8rQQ0/UUui6zm////w==...
# https://adcr.naver.com/adcr?x=4OHXuRmA8rQQ0/UUui6zm////w==...&amp;p=1
# https://adcr.naver.com/adcr?x=4OHXuRmA8rQQ0/UUui6zm////w==...&amp;p=1
# https://adcr.naver.com/adcr?x=4OHXuRmA8rQQ0/UUui6zm////w==...&amp;p=0
# https://adcr.naver.com/adcr?x=4OHXuRmA8rQQ0/UUui6zm////w==...
# https://adcr.naver.com/adcr?x=a6O9PfFooKXomhbvmgdiif///w==...
# https://m.pay.naver.com/mobile/about
# https://adcr.naver.com/adcr?x=a6O9PfFooKXomhbvmgdiif///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=a6O9PfFooKXomhbvmgdiif///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=a6O9PfFooKXomhbvmgdiif///w==...&amp;p=0
# https://adcr.naver.com/adcr?x=a6O9PfFooKXomhbvmgdiif///w==...
# https://adcr.naver.com/adcr?x=taMccq7mRmVoCgWyYFlJlf///w==...
# https://adcr.naver.com/adcr?x=Zg3Ngm2h2IZqnarSbTkVv////w==...
# https://adcr.naver.com/adcr?x=mvEom8yyb/wiGGUnWXbXIP///w==...
# https://adcr.naver.com/adcr?x=0bpHI8HJElRzIOP9NzunIv///w==...
# https://adcr.naver.com/adcr?x=Q4oP6DfASs2qrFuKIdOfm////w==...
# https://adcr.naver.com/adcr?x=Q4oP6DfASs2qrFuKIdOfm////w==...&amp;p=1
# https://adcr.naver.com/adcr?x=Q4oP6DfASs2qrFuKIdOfm////w==...&amp;p=1
# https://adcr.naver.com/adcr?x=Q4oP6DfASs2qrFuKIdOfm////w==...&amp;p=0
# https://adcr.naver.com/adcr?x=Q4oP6DfASs2qrFuKIdOfm////w==...
# https://adcr.naver.com/adcr?x=VQuOUxN03WFXvQZsU1d8yf///w==...
yJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6Imltc2FuYnUiLCJhcnRpY2xlSWQiOjczMzE3MDcyLCJpc3N1ZWRBdCI6MTczMjUwMTk3MDU0MX0.A3SJI1Vwcyrbfm6pIM92kfp5X_-mSQZaMV9SOLt38cY
# https://cafe.naver.com/directwedding
# https://cafe.naver.com/directwedding
# https://cafe.naver.com/directwedding
# https://cafe.naver.com/makegoodstudy
# https://cafe.naver.com/makegoodstudy
# https://cafe.naver.com/makegoodstudy
# https://cafe.naver.com/jpnstory
# https://cafe.naver.com/jpnstory
# https://cafe.naver.com/jpnstory
# ?nso=&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;where=nexearch
# ?nso=&amp;page=2&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=1&amp;where=web
# ?nso=&amp;page=3&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=16&amp;where=web
# ?nso=&amp;page=4&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=31&amp;where=web
# ?nso=&amp;page=5&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=46&amp;where=web
# ?nso=&amp;page=6&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=61&amp;where=web
# ?nso=&amp;page=7&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=76&amp;where=web
# ?nso=&amp;page=8&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=91&amp;where=web
# ?nso=&amp;page=9&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=106&amp;where=web
# https://ssl.pstatic.net/sstatic/search/pc/css/sp_viewer_241121.css

# %%
conda install beautifulsoup4
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_line_magic('conda', 'install beautifulsoup4')
#
# File D:\python_basic\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File D:\python_basic\Lib\site-packages\IPython\core\magics\packaging.py:30, in is_conda_environment.<locals>.wrapper(*args, **kwargs)
#      25 if not Path(sys.prefix, "conda-meta", "history").exists():
#      26     raise ValueError(
#      27         "The python kernel does not appear to be a conda environment.  "
#      28         "Please use ``%pip install`` instead."
#      29     )
# ---> 30 return func(*args, **kwargs)
#
# File D:\python_basic\Lib\site-packages\IPython\core\magics\packaging.py:128, in PackagingMagics.conda(self, line)
#     120 @line_magic
#     121 @is_conda_environment
#     122 def conda(self, line):
#     123     """Run the conda package manager within the current kernel.
#     124
#     125     Usage:
#     126       %conda install [pkgs]
#     127     """
# --> 128     conda = _get_conda_like_executable("conda")
#     129     self._run_command(conda, line)
#
# File D:\python_basic\Lib\site-packages\IPython\core\magics\packaging.py:53, in _get_conda_like_executable(command)
#      50 # Otherwise, attempt to extract the executable from conda history.
#      51 # This applies in any conda environment.
#      52 history = Path(sys.prefix, "conda-meta", "history").read_text(encoding="utf-8")
# ---> 53 match = re.search(
#      54     rf"^#\s*cmd:\s*(?P<command>.*{executable})\s[create|install]",
#      55     history,
#      56     flags=re.MULTILINE,
#      57 )
#      58 if match:
#      59     return match.groupdict()["command"]
#
# File D:\python_basic\Lib\re\__init__.py:177, in search(pattern, string, flags)
#     174 def search(pattern, string, flags=0):
#     175     """Scan through string looking for a match to the pattern, returning
#     176     a Match object, or None if no match was found."""
# --> 177     return _compile(pattern, flags).search(string)
#
# File D:\python_basic\Lib\re\__init__.py:307, in _compile(pattern, flags)
#     301     import warnings
#     302     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     303             "as it is an undocumented flag "
#     304             "without an obvious purpose. "
#     305             "Don't use it.",
#     306             DeprecationWarning)
# --> 307 p = _compiler.compile(pattern, flags)
#     308 if flags & DEBUG:
#     309     return p
#
# File D:\python_basic\Lib\re\_compiler.py:745, in compile(p, flags)
#     743 if isstring(p):
#     744     pattern = p
# --> 745     p = _parser.parse(p, flags)
#     746 else:
#     747     pattern = None
#
# File D:\python_basic\Lib\re\_parser.py:979, in parse(str, flags, state)
#     976 state.flags = flags
#     977 state.str = str
# --> 979 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     980 p.state.flags = fix_flags(str, p.state.flags)
#     982 if source.next is not None:
#
# File D:\python_basic\Lib\re\_parser.py:460, in _parse_sub(source, state, verbose, nested)
#     458 start = source.tell()
#     459 while True:
# --> 460     itemsappend(_parse(source, state, verbose, nested + 1,
#     461                        not nested and not items))
#     462     if not sourcematch("|"):
#     463         break
#
# File D:\python_basic\Lib\re\_parser.py:862, in _parse(source, state, verbose, nested, first)
#     859     group = None
#     860 sub_verbose = ((verbose or (add_flags & SRE_FLAG_VERBOSE)) and
#     861                not (del_flags & SRE_FLAG_VERBOSE))
# --> 862 p = _parse_sub(source, state, sub_verbose, nested + 1)
#     863 if not source.match(")"):
#     864     raise source.error("missing ), unterminated subpattern",
#     865                        source.tell() - start)
#
# File D:\python_basic\Lib\re\_parser.py:460, in _parse_sub(source, state, verbose, nested)
#     458 start = source.tell()
#     459 while True:
# --> 460     itemsappend(_parse(source, state, verbose, nested + 1,
#     461                        not nested and not items))
#     462     if not sourcematch("|"):
#     463         break
#
# File D:\python_basic\Lib\re\_parser.py:544, in _parse(source, state, verbose, nested, first)
#     541         continue
#     543 if this[0] == "\\":
# --> 544     code = _escape(source, this, state)
#     545     subpatternappend(code)
#     547 elif this not in SPECIAL_CHARS:
#
# File D:\python_basic\Lib\re\_parser.py:443, in _escape(source, escape, state)
#     441     if len(escape) == 2:
#     442         if c in ASCIILETTERS:
# --> 443             raise source.error("bad escape %s" % escape, len(escape))
#     444         return LITERAL, ord(escape[1])
#     445 except ValueError:
#
# error: bad escape \p at position 28

# %%
from bs4 import BeutifulSoup as bs
soup = bs(html_text, 'html.patser')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from bs4 import BeutifulSoup as bs
#       2 soup = bs(html_text, 'html.patser')
#
# ImportError: cannot import name 'BeutifulSoup' from 'bs4' (D:\python_basic\Lib\site-packages\bs4\__init__.py)

# %%
items = soup.select("a.news_tit")
for item in items:
    href = item.attrs['href']
    print(href)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 items = soup.select("a.news_tit")
#       2 for item in items:
#       3     href = item.attrs['href']
#
# NameError: name 'soup' is not defined
